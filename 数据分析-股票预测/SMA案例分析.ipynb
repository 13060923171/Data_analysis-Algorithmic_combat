# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('bitcoin_2012-01-01_to_2018-10-31.csv')
df.index = df.iloc[:,0]

# %%
df.head()
# Out:
#              Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# Timestamp
# 2011/12/31  2011/12/31  4.465000  4.482500  4.465000  4.482500     23.829470
# 2012/1/1      2012/1/1  4.806667  4.806667  4.806667  4.806667      7.200667
# 2012/1/2      2012/1/2  5.000000  5.000000  5.000000  5.000000     19.048000
# 2012/1/3      2012/1/3  5.252500  5.252500  5.252500  5.252500     11.004660
# 2012/1/4      2012/1/4  5.200000  5.223333  5.200000  5.223333     11.914807
#
#             Volume_(Currency)  Weighted_Price
# Timestamp
# 2011/12/31         106.330084        4.471603
# 2012/1/1            35.259720        4.806667
# 2012/1/2            95.240000        5.000000
# 2012/1/3            58.100651        5.252500
# 2012/1/4            63.119578        5.208159

# %%
close = df.Close

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.plot(close,'b')
plt.xlabel('date')
plt.ylabel('close')
plt.title('比特币收盘价时序图')
# Out:
# Text(0.5, 1.0, '比特币收盘价时序图')

# %%
sma5 = pd.Series(0.0,index=close.index)
for i in range(4,len(close)):
    sma5[i] = np.mean(close[(i-4):(i+1)])
sma5.tail()
# Out:
# Timestamp
# 2018/10/27    6405.729595
# 2018/10/28    6407.147722
# 2018/10/29    6387.101400
# 2018/10/30    6359.823880
# 2018/10/31    6335.216514
# dtype: float64

# %%
plt.figure(figsize=(16,12))
plt.plot(close[4:],label='Close',color='g')
plt.plot(sma5[4:],label='sma5',color='r',linestyle='dashed')
plt.title('比特币价格图')
plt.legend()

# %%
sma20 = pd.Series(0.0,index=close.index)
for i in range(19,len(close)):
    sma20[i] = np.mean(close[(i-19):(i+1)])
sma20.tail()
# Out:
# Timestamp
# 2018/10/27    6392.799750
# 2018/10/28    6383.505942
# 2018/10/29    6370.415743
# 2018/10/30    6357.860618
# 2018/10/31    6361.089875
# dtype: float64

# %%
plt.figure(figsize=(16,12))
plt.plot(close[4:],label='Close',color='g')
plt.plot(sma5[4:],label='sma5',color='r',linestyle='dashed')
plt.plot(sma20[19:],label='sma20',color='b',linestyle='dashed')
plt.title('比特币价格图')
plt.legend()
