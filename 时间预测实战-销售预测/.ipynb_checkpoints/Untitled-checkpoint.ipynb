# %%
import pandas as pd
import numpy as np

# %%
df_total = pd.read_excel("Table 89 3.xlsx",sheet_name='总体').loc[:,['Unnamed: 0','百万港元','指数','按年变动百分率','指数.1','按年变动百分率.1']]
df_total = df_total.replace('N.A.',np.nan)
df_total.dropna(axis=0,how='any',inplace=True)
df_total
# Out:
#     Unnamed: 0      百万港元     指数  按年变动百分率   指数.1  按年变动百分率.1
# 2         2006  219002.0   45.3      7.2   54.8        5.6
# 3         2007  247000.0   51.1     12.8   60.2        9.9
# 4         2008  273126.0   56.5     10.6   63.1        4.7
# 5         2009  274742.0   56.8      0.6   62.4       -1.0
# 6         2010  324966.0   67.2     18.3   71.7       14.8
# 7         2011  405732.0   83.9     24.9   84.9       18.4
# 8         2012  445498.0   92.1      9.8   90.6        6.8
# 9         2013  494451.0  102.3     11.0  100.6       11.0
# 10        2014  493236.0  102.0     -0.2  100.4       -0.2
# 11        2015  475156.0   98.3     -3.7   98.9       -1.5
# 12        2016  436623.0   90.3     -8.1   91.9       -7.1
# 13        2017  446136.0   92.3      2.2   93.6        1.9
# 14        2018  485169.0  100.3      8.7  100.7        7.6
# 15        2019  431160.0   89.2    -11.1   88.3      -12.3
# 16        2020  326451.0   67.5    -24.3   65.8      -25.5

# %%
def dispose_df(year):
    df_total = pd.read_excel("Table 89 3.xlsx", sheet_name='{}'.format(year)).loc[:,
               ['Unnamed: 0', '百万港元', '指数', '按年变动百分率', '指数.1', '按年变动百分率.1']]

    df_total = df_total.replace('N.A.', np.nan)
    df_total.dropna(axis=0, how='any', inplace=True)
    def double_df(x):
        return str(year) + "-" + str(x)
    df_total['Unnamed: 0'] = df_total['Unnamed: 0'].apply(double_df)

    return df_total

# %%
frames = []
for i in range(2004,2022):
    df = dispose_df(i)
    frames.append(df)

result = pd.concat(frames)
result.columns = ['year','money','index','variation','index2','variation2']
#将时间作为表格的索引
result.year = pd.to_datetime(result.year)
result.index = result.year
result
# Out:
#                  year    money  index  variation  index2  variation2
# year
# 2005-10-01 2005-10-01  16588.0   41.2        4.8    50.0         4.3
# 2005-11-01 2005-11-01  15760.0   39.1        4.1    47.3         4.0
# 2005-12-01 2005-12-01  19251.0   47.8        6.8    58.2         7.0
# 2006-01-01 2006-01-01  21112.0   52.4       11.5    64.8        11.6
# 2006-02-01 2006-02-01  16132.0   40.0       -3.3    49.4        -4.0
# ...               ...      ...    ...        ...     ...         ...
# 2021-04-01 2021-04-01  27018.0   67.0       12.1    64.3        11.0
# 2021-05-01 2021-05-01  29565.0   73.4       10.4    70.1         7.7
# 2021-06-01 2021-06-01  28074.0   69.7        5.8    66.4         2.9
# 2021-07-01 2021-07-01  27203.0   67.5        2.8    64.7         0.7
# 2021-08-01 2021-08-01  28598.0   71.0       11.9    68.4        10.6
#
# [191 rows x 6 columns]

# %%
from statsmodels.graphics.tsaplots import acf,pacf,plot_acf,plot_pacf
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
data = result.money
#原始数据之后的时间趋势
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(111)
data.plot(ax=ax1)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
#由于上图不是很平稳，所以对该时间进行时间序列的差分，找出合适的差分次数
#这个是一阶差分，可以看出时间序列的均值和方差基本平稳
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(111)
diff1 = data.diff(1)
diff1.plot(ax=ax1)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
data = data.diff(1)
data.dropna(inplace=True)
#找出arima模型中合适的p和q值
#先检查平稳序列的自相关图和偏自相关图
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_acf(data,lags=40,ax=ax1)
data
# Out:
# year
# 2005-11-01    -828.0
# 2005-12-01    3491.0
# 2006-01-01    1861.0
# 2006-02-01   -4980.0
# 2006-03-01    1778.0
#                ...
# 2021-04-01    -608.0
# 2021-05-01    2547.0
# 2021-06-01   -1491.0
# 2021-07-01    -871.0
# 2021-08-01    1395.0
# Name: money, Length: 190, dtype: float64

# %%
fig = plt.figure(figsize=(12,8))
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(data,lags=40,ax=ax2)

# %%
from itertools import product
import warnings
from tqdm import tqdm
warnings.filterwarnings('ignore')
#设置参数范围
ps = [8]
qs = [9]
parameters = product(ps,qs)
parameters_list = list(parameters)


#寻找最优arma模型参数，即best_aic最小
results = []
#正无穷
best_aic = float('inf')

for param in tqdm(parameters_list):
    try:
        model = ARMA(data,order=(param[0],param[1])).fit()
    except:
#         print('参数错误:',param)
        continue
    aic = model.aic
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param,model.aic])

#输出最优模型
result_table = pd.DataFrame(results)
result_table.columns = ['parameters','aic']
print('最优模型:',best_model.summary())
# Out:
# 100%|██████████| 1/1 [01:29<00:00, 89.22s/it]
# 最优模型:                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  money   No. Observations:                  190
# Model:                     ARMA(8, 9)   Log Likelihood               -1726.471
# Method:                       css-mle   S.D. of innovations           2027.064
# Date:                Tue, 19 Oct 2021   AIC                           3490.941
# Time:                        17:40:21   BIC                           3552.635
# Sample:                    11-01-2005   HQIC                          3515.933
#                          - 08-01-2021
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          62.8885     76.385      0.823      0.410     -86.824     212.601
# ar.L1.money     0.9967      0.006    169.922      0.000       0.985       1.008
# ar.L2.money    -1.0207      0.015    -66.043      0.000      -1.051      -0.990
# ar.L3.money    -0.0155      0.026     -0.603      0.547      -0.066       0.035
# ar.L4.money     0.0446      0.037      1.193      0.233      -0.029       0.118
# ar.L5.money    -0.0804      0.022     -3.676      0.000      -0.123      -0.038
# ar.L6.money    -0.9240      0.008   -117.182      0.000      -0.939      -0.909
# ar.L7.money     0.9318        nan        nan        nan         nan         nan
# ar.L8.money    -0.9657      0.004   -228.035      0.000      -0.974      -0.957
# ma.L1.money    -1.3586        nan        nan        nan         nan         nan
# ma.L2.money     1.3168        nan        nan        nan         nan         nan
# ma.L3.money    -0.2038      0.082     -2.475      0.013      -0.365      -0.042
# ma.L4.money    -0.3267      0.085     -3.839      0.000      -0.493      -0.160
# ma.L5.money     0.2919      0.086      3.406      0.001       0.124       0.460
# ma.L6.money     0.7706      0.127      6.051      0.000       0.521       1.020
# ma.L7.money    -1.3361      0.100    -13.329      0.000      -1.533      -1.140
# ma.L8.money     1.3774        nan        nan        nan         nan         nan
# ma.L9.money    -0.4839        nan        nan        nan         nan         nan
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.8819           -0.4989j            1.0132           -0.4181
# AR.2           -0.8819           +0.4989j            1.0132            0.4181
# AR.3            0.0041           -1.0000j            1.0000           -0.2494
# AR.4            0.0041           +1.0000j            1.0000            0.2494
# AR.5            0.8660           -0.5073j            1.0036           -0.0843
# AR.6            0.8660           +0.5073j            1.0036            0.0843
# AR.7            0.4943           -0.8701j            1.0007           -0.1678
# AR.8            0.4943           +0.8701j            1.0007            0.1678
# MA.1           -0.8881           -0.4609j            1.0006           -0.4238
# MA.2           -0.8881           +0.4609j            1.0006            0.4238
# MA.3            0.0046           -1.0040j            1.0040           -0.2493
# MA.4            0.0046           +1.0040j            1.0040            0.2493
# MA.5            0.4784           -0.8840j            1.0051           -0.1711
# MA.6            0.4784           +0.8840j            1.0051            0.1711
# MA.7            0.8832           -0.5405j            1.0355           -0.0874
# MA.8            0.8832           +0.5405j            1.0355            0.0874
# MA.9            1.8904           -0.0000j            1.8904           -0.0000
# -----------------------------------------------------------------------------

# %%
#在选出模型检验之后，对哦arma模型所产生的残差做相关图
resid = best_model.resid

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(resid,lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(resid,lags=40,ax=ax2)

# %%
#用德宾-沃森(D-W)检验
# DW＝４＜＝＞ρ＝－１　即存在负自相关性
# DW＝２＜＝＞ρ＝０　　即不存在（一阶）自相关性
#残差序列不存在自相关性
sm.stats.durbin_watson(best_model.resid)
# Out:
# 2.1190050246539927

# %%
#基本符合正态分布
from statsmodels.graphics.api import qqplot
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
fig = qqplot(resid, line='q', ax=ax, fit=True)

# %%
#用Ljung-box检验:检验结果就是看最后一列前十二行的检验概率
#prob值均大于0.05，所以残差序列不存在自相关性
r,q,p = sm.tsa.acf(resid.squeeze(),qstat=True)
data1 = np.c_[range(1,41),r[1:],q,p]
table = pd.DataFrame(data1,columns=['lag','AC','Q','Prob(>Q)'])
table.set_index('lag')
# Out:
#             AC           Q      Prob(>Q)
# lag
# 1.0  -0.060727    0.711803  3.988460e-01
# 2.0  -0.018966    0.781600  6.765153e-01
# 3.0   0.155692    5.510365  1.380200e-01
# 4.0  -0.023235    5.616251  2.296983e-01
# 5.0  -0.047409    6.059459  3.004763e-01
# 6.0   0.223188   15.935383  1.410503e-02
# 7.0  -0.012477   15.966418  2.542495e-02
# 8.0  -0.083274   17.356361  2.660498e-02
# 9.0   0.210249   26.265677  1.848131e-03
# 10.0 -0.084884   27.725954  1.996837e-03
# 11.0  0.052418   28.285928  2.926247e-03
# 12.0  0.217845   38.011797  1.528802e-04
# 13.0 -0.008677   38.027315  2.854350e-04
# 14.0 -0.115621   40.798187  1.913518e-04
# 15.0  0.086738   42.366517  1.973401e-04
# 16.0 -0.080633   43.729633  2.168010e-04
# 17.0 -0.045384   44.163959  3.239466e-04
# 18.0  0.069936   45.201303  3.875539e-04
# 19.0 -0.071772   46.300224  4.493691e-04
# 20.0 -0.074208   47.481931  5.026610e-04
# 21.0  0.108154   50.006875  3.639977e-04
# 22.0 -0.029850   50.200353  5.509767e-04
# 23.0 -0.068847   51.235760  6.326062e-04
# 24.0  0.155229   56.531052  1.939433e-04
# 25.0 -0.072079   57.679706  2.166083e-04
# 26.0 -0.140662   62.080829  8.751242e-05
# 27.0  0.082813   63.615667  8.687971e-05
# 28.0 -0.070909   64.747927  9.740082e-05
# 29.0 -0.066359   65.745703  1.131541e-04
# 30.0  0.121241   69.097142  6.406549e-05
# 31.0 -0.069941   70.219479  7.153570e-05
# 32.0 -0.063335   71.145637  8.430129e-05
# 33.0  0.126000   74.834550  4.340066e-05
# 34.0 -0.112876   77.813990  2.762247e-05
# 35.0 -0.128591   81.705752  1.331699e-05
# 36.0  0.338305  108.817164  3.046072e-09
# 37.0 -0.110477  111.727251  1.977993e-09
# 38.0 -0.057169  112.511644  2.676700e-09
# 39.0  0.112713  115.580823  1.644943e-09
# 40.0 -0.020190  115.679962  2.789553e-09

# %%
delta = best_model.fittedvalues - data
#它的值在0-1之间，越接近1，拟合效果越好
score = 1 - delta.var() / data.var()
score
# Out:
# 0.6012552560612503

# %%
from datetime import datetime
#转换成一维数值
data = pd.Series(data)
#预测后面几个月的趋势
predict_data = best_model.predict(start=len(data)-2,end=len(data)+6)
#定义画布大小
fig,ax = plt.subplots(figsize=(12,8))
#引入数据
ax = data.loc['2005-11-01':].plot(ax=ax)
predict_data.plot(ax=ax)
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus']=False
plt.title('销售时间预测')
plt.xlabel('时间')
plt.ylabel('趋势')
plt.show()
